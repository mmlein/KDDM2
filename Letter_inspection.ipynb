# %% [markdown]
# Read libraries

# %%
import scipy.io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read data

# %%
letter_dict = scipy.io.loadmat('letter.mat')
letter_df_X = pd.DataFrame(letter_dict['X'])
letter_df_y = pd.DataFrame(letter_dict['y'])

# %% [markdown]
# Correlation matrix

# %%
corrmat = letter_df_X.corr()
round(corrmat,2)
sns.heatmap(corrmat)
plt.show()

# %% [markdown]
# Data inspection

# %% [markdown]
# General analysis

# %%
letter_df_X[[5, 6, 7, 8, 9, 10]].describe()
# Out:
#                 5            6            7            8            9   \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean      7.193125     8.225625     3.596875     5.201875     8.545000
# std       1.482296     2.747169     3.032963     2.085087     2.512602
# min       3.000000     2.000000     0.000000     0.000000     4.000000
# 25%       7.000000     7.000000     2.000000     4.000000     7.000000
# 50%       7.000000     7.000000     3.000000     5.000000     7.000000
# 75%       8.000000    10.250000     5.000000     7.000000    11.000000
# max      13.000000    15.000000    13.000000    10.000000    14.000000
#
#                 10
# count  1600.000000
# mean      7.309375
# std       2.216525
# min       1.000000
# 25%       6.000000
# 50%       7.000000
# 75%       9.000000
# max      12.000000

# %%
sub_df = letter_df_X.loc[:, 5:10]
sns.pairplot(sub_df)
plt.show()

# %% [markdown]
# ### Feature #6:
# "The mean horizontal position of all "on" pixels relative to the center of the box and divided by the width of the box. This feature has a negative value if the image is "left-heavy" as would be the case for the letter L." <br> <br>
# *Comment: I assume that in this case the data was not centered, and the letter L would have a mean of < 7.5*

# %%
plt.figure()
sns.displot(letter_df_X[5], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[5])
plt.show()

# %% [markdown]
# ### Feature #7:
# "The mean vertical position of all "on" pixels relative to the center of the box and divided by the height of the box."

# %%
plt.figure()
sns.displot(letter_df_X[6], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[6])
plt.show()

# %% [markdown]
# ### Feature #8:
# "The mean squared value of the horizontal pixel distances as measured in 6 above. This attribute will have a higher valuer for images whose pixels are more widely separated in the horizontal direction as would be the case for the letters W or M."

# %%
plt.figure()
sns.displot(letter_df_X[7], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[7])
plt.show()

# %% [markdown]
# ### Feature #9:
# "The mean squared value of the the vertical pixel distances as measured in 7 above."

# %%
plt.figure()
sns.displot(letter_df_X[8], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[8])
plt.show()

# %% [markdown]
# ### Feature #10:
# "The mean product of the horizontal and vertical distances for each "on" pixel as measured  in 6 and 7 above. This attribute has a positive value for diagonal lines that run from bottom left to ttop right and a negative value for diagonal lines from top left to bottom right."

# %%
plt.figure()
sns.displot(letter_df_X[9], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[9])
plt.show()

# %% [markdown]
# ### Feature #11:
# "The mean value of the squared horizomtal distance times the vertical distance for each "on" pixel. This measures the correlation of the vertical variance with the horizontal position."

# %%
plt.figure()
sns.displot(letter_df_X[10], kde = True)
plt.show()
plt.figure()
sns.boxplot(x = letter_df_X[10])
plt.show()
